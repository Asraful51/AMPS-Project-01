# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("2.Student_Mental_Stress_and_Coping_Mechanisms.csv")

# %%
data.head()
# Out:
#     Student_ID  Age  Gender  Academic_Performance_(GPA)  Study_Hours_Per_Week  \
# 0  802-17-3671   22  Female                           2                     9
# 1  871-12-8572   25  Female                           0                    28
# 2  495-13-2672   24  Female                           0                    45
# 3  365-77-2496   20    Male                           2                     8
# 4  664-76-5622   28    Male                           0                    14
#
#    Social_Media_Usage_(Hours_per_day)  Sleep_Duration_(Hours_per_night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
# ...

# %%
data.describe()
# Out:
#               Age  Academic_Performance_(GPA)  Study_Hours_Per_Week  \
# count  760.000000                  760.000000            760.000000
# mean    23.919737                    1.996053             29.130263
# std      3.819392                    1.416535             18.104662
# min     18.000000                    0.000000              0.000000
# 25%     21.000000                    1.000000             13.000000
# 50%     24.000000                    2.000000             29.000000
# 75%     27.000000                    3.000000             45.000000
# max     30.000000                    4.000000             60.000000
#
#        Social_Media_Usage_(Hours_per_day)  Sleep_Duration_(Hours_per_night)  \
# count                          760.000000                        760.000000
# mean                             4.234211                          8.093421
# std                              2.565174                          2.596838
# ...

# %%
data[['Age', 'Study_Hours_Per_Week', 'Mental_Stress_Level']].describe()
# Out:
#               Age  Study_Hours_Per_Week  Mental_Stress_Level
# count  760.000000            760.000000           760.000000
# mean    23.919737             29.130263             5.363158
# std      3.819392             18.104662             2.902856
# min     18.000000              0.000000             1.000000
# 25%     21.000000             13.000000             3.000000
# 50%     24.000000             29.000000             5.000000
# 75%     27.000000             45.000000             8.000000
# max     30.000000             60.000000            10.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Student_ID                          760 non-null    str
#  1   Age                                 760 non-null    int64
#  2   Gender                              760 non-null    str
#  3   Academic_Performance_(GPA)          760 non-null    int64
#  4   Study_Hours_Per_Week                760 non-null    int64
#  5   Social_Media_Usage_(Hours_per_day)  760 non-null    int64
#  6   Sleep_Duration_(Hours_per_night)    760 non-null    int64
#  7   Physical_Exercise_(Hours_per_week)  760 non-null    int64
#  8   Family_Support                      760 non-null    int64
#  9   Financial_Stress                    760 non-null    int64
#  10  Peer_Pressure                       760 non-null    int64
# ...

# %%
data.isnull()
# Out:
#      Student_ID    Age  Gender  Academic_Performance_(GPA)  \
# 0         False  False   False                       False
# 1         False  False   False                       False
# 2         False  False   False                       False
# 3         False  False   False                       False
# 4         False  False   False                       False
# ..          ...    ...     ...                         ...
# 755       False  False   False                       False
# 756       False  False   False                       False
# 757       False  False   False                       False
# 758       False  False   False                       False
# 759       False  False   False                       False
#
#      Study_Hours_Per_Week  Social_Media_Usage_(Hours_per_day)  \
# 0                   False                               False
# 1                   False                               False
# 2                   False                               False
# ...

# %%
data.isnull().sum()
# Out:
# Student_ID                            0
# Age                                   0
# Gender                                0
# Academic_Performance_(GPA)            0
# Study_Hours_Per_Week                  0
# Social_Media_Usage_(Hours_per_day)    0
# Sleep_Duration_(Hours_per_night)      0
# Physical_Exercise_(Hours_per_week)    0
# Family_Support                        0
# Financial_Stress                      0
# Peer_Pressure                         0
# Relationship_Stress                   0
# Mental_Stress_Level                   0
# Counseling_Attendance                 0
# Diet_Quality                          0
# Stress_Coping_Mechanisms              0
# Cognitive_Distortions                 0
# Family_Mental_Health_History          0
# Medical_Condition                     0
# Substance_Use                         0
# dtype: int64

# %%
data.loc[data['Age'] == 30]
# Out:
#       Student_ID  Age   Gender  Academic_Performance_(GPA)  \
# 21   861-60-5151   30  Agender                           0
# 46   532-53-7106   30     Male                           4
# 62   683-65-1968   30     Male                           3
# 64   209-32-8628   30     Male                           0
# 67   800-36-7705   30   Female                           0
# ..           ...  ...      ...                         ...
# 737  345-50-9214   30     Male                           3
# 744  626-36-8884   30   Female                           0
# 746  143-10-3794   30   Female                           2
# 747  386-97-0412   30     Male                           4
# 752  527-24-3188   30     Male                           1
#
#      Study_Hours_Per_Week  Social_Media_Usage_(Hours_per_day)  \
# 21                     37                                   4
# 46                     28                                   7
# 62                      0                                   1
# ...

# %%
data.loc[(data['Age'] == 30) & (data['Academic_Performance_(GPA)'] == 4) & (data['Gender'] == 'Male')]
# Out:
#       Student_ID  Age Gender  Academic_Performance_(GPA)  \
# 46   532-53-7106   30   Male                           4
# 91   631-57-6187   30   Male                           4
# 460  593-90-7730   30   Male                           4
# 486  757-52-0603   30   Male                           4
# 544  330-13-8536   30   Male                           4
# 603  670-07-5476   30   Male                           4
# 747  386-97-0412   30   Male                           4
#
#      Study_Hours_Per_Week  Social_Media_Usage_(Hours_per_day)  \
# 46                     28                                   7
# 91                     42                                   2
# 460                    36                                   4
# 486                     8                                   6
# 544                    44                                   5
# 603                    43                                   4
# 747                    17                                   0
#
# ...

# %%
data.loc[(data['Age'] == 30) & (data['Academic_Performance_(GPA)'] == 4) & (data['Gender'] == 'Male')].head()
# Out:
#       Student_ID  Age Gender  Academic_Performance_(GPA)  \
# 46   532-53-7106   30   Male                           4
# 91   631-57-6187   30   Male                           4
# 460  593-90-7730   30   Male                           4
# 486  757-52-0603   30   Male                           4
# 544  330-13-8536   30   Male                           4
#
#      Study_Hours_Per_Week  Social_Media_Usage_(Hours_per_day)  \
# 46                     28                                   7
# 91                     42                                   2
# 460                    36                                   4
# 486                     8                                   6
# 544                    44                                   5
#
#      Sleep_Duration_(Hours_per_night)  Physical_Exercise_(Hours_per_week)  \
# 46                                 11                                   6
# 91                                  7                                   5
# ...

# %%
data.iloc[100:110, 2:6]
# Out:
#        Gender  Academic_Performance_(GPA)  Study_Hours_Per_Week  \
# 100      Male                           3                     8
# 101    Female                           1                    59
# 102      Male                           2                    54
# 103      Male                           3                     7
# 104    Female                           4                    57
# 105  Bigender                           4                    29
# 106    Female                           2                     3
# 107      Male                           4                     3
# 108    Female                           2                    36
# 109      Male                           1                    53
#
#      Social_Media_Usage_(Hours_per_day)
# 100                                   4
# 101                                   1
# 102                                   4
# 103                                   7
# 104                                   8
# ...

# %%
data.iloc[100:110, [2,6]]
# Out:
#        Gender  Sleep_Duration_(Hours_per_night)
# 100      Male                                 9
# 101    Female                                 7
# 102      Male                                10
# 103      Male                                 8
# 104    Female                                 5
# 105  Bigender                                12
# 106    Female                                 9
# 107      Male                                10
# 108    Female                                11
# 109      Male                                 9

# %%
data.loc[data['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Academic_Performance_(GPA), Study_Hours_Per_Week, Social_Media_Usage_(Hours_per_day), Sleep_Duration_(Hours_per_night), Physical_Exercise_(Hours_per_week), Family_Support, Financial_Stress, Peer_Pressure, Relationship_Stress, Mental_Stress_Level, Counseling_Attendance, Diet_Quality, Stress_Coping_Mechanisms, Cognitive_Distortions, Family_Mental_Health_History, Medical_Condition, Substance_Use]
# Index: []

# %%
data['Academic_Performance_(GPA)'].value_counts()
# Out:
# Academic_Performance_(GPA)
# 3    170
# 0    161
# 2    149
# 4    143
# 1    137
# Name: count, dtype: int64

# %%
data.sort_values('Academic_Performance_(GPA)')
# Out:
#       Student_ID  Age   Gender  Academic_Performance_(GPA)  \
# 749  593-06-7718   25     Male                           0
# 1    871-12-8572   25   Female                           0
# 2    495-13-2672   24   Female                           0
# 744  626-36-8884   30   Female                           0
# 4    664-76-5622   28     Male                           0
# ..           ...  ...      ...                         ...
# 429  651-96-1453   20     Male                           4
# 24   589-36-1147   28     Male                           4
# 23   115-75-7195   28  Agender                           4
# 747  386-97-0412   30     Male                           4
# 754  836-77-4994   19     Male                           4
#
#      Study_Hours_Per_Week  Social_Media_Usage_(Hours_per_day)  \
# 749                    15                                   5
# 1                      28                                   0
# 2                      45                                   3
# ...

# %%
data2 = pd.read_csv("2.Student_Mental_Stress_and_Coping_Mechanisms.csv")

# %%
mcp = np.array(data2['Study_Hours_Per_Week'])
inc = mcp / 7
incr_col = pd.DataFrame(inc, columns=['Study_Hour_Per_Day'])
data2 = pd.concat([data2, incr_col], axis = 1)
data2.head()
# Out:
#     Student_ID  Age  Gender  Academic_Performance_(GPA)  Study_Hours_Per_Week  \
# 0  802-17-3671   22  Female                           2                     9
# 1  871-12-8572   25  Female                           0                    28
# 2  495-13-2672   24  Female                           0                    45
# 3  365-77-2496   20    Male                           2                     8
# 4  664-76-5622   28    Male                           0                    14
#
#    Social_Media_Usage_(Hours_per_day)  Sleep_Duration_(Hours_per_night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
# ...

# %%
data2.drop(columns=['Study_Hours_Per_Week'])
# Out:
#       Student_ID  Age       Gender  Academic_Performance_(GPA)  \
# 0    802-17-3671   22       Female                           2
# 1    871-12-8572   25       Female                           0
# 2    495-13-2672   24       Female                           0
# 3    365-77-2496   20         Male                           2
# 4    664-76-5622   28         Male                           0
# ..           ...  ...          ...                         ...
# 755  826-89-7993   24  Genderfluid                           2
# 756  681-15-6754   23       Female                           3
# 757  714-33-5373   23         Male                           1
# 758  849-54-1252   29       Female                           1
# 759  862-68-5364   21       Female                           3
#
#      Social_Media_Usage_(Hours_per_day)  Sleep_Duration_(Hours_per_night)  \
# 0                                     2                                12
# ...

# %%
data.groupby('Gender')['Academic_Performance_(GPA)'].unique().reset_index()
# Out:
#         Gender Academic_Performance_(GPA)
# 0      Agender            [0, 4, 1, 3, 2]
# 1     Bigender            [3, 2, 4, 1, 0]
# 2       Female            [2, 0, 1, 3, 4]
# 3  Genderfluid            [4, 1, 0, 3, 2]
# 4  Genderqueer               [1, 3, 2, 0]
# 5         Male            [2, 0, 3, 1, 4]
# 6   Non-binary               [4, 2, 1, 3]
# 7   Polygender               [3, 2, 0, 4]

# %%
data.groupby('Gender', as_index=False)['Academic_Performance_(GPA)'].median()
# Out:
#         Gender  Academic_Performance_(GPA)
# 0      Agender                         1.5
# 1     Bigender                         2.0
# 2       Female                         2.0
# 3  Genderfluid                         2.5
# 4  Genderqueer                         2.0
# 5         Male                         2.0
# 6   Non-binary                         2.5
# 7   Polygender                         2.5

# %%
data['Study_Hours_Per_Week'].unique()
# Out:
# array([ 9, 28, 45,  8, 14, 27, 30, 12, 19,  4, 38,  2, 39, 44, 49, 26, 54,
#        35, 37, 21, 58, 32, 13, 46, 43,  7, 11, 34, 36, 40, 15,  6, 25, 59,
#        17, 10,  5, 48, 60, 20,  0, 24, 18,  1, 31, 57, 53, 41, 50, 16, 42,
#        51, 33, 47, 29,  3, 23, 55, 56, 22, 52])

# %%
data['Counseling_Attendance'] = pd.to_numeric(data['Counseling_Attendance'].str.replace('Yes', '1').str.replace('No', '0'))
data.dtypes
# Out:
# Student_ID                              str
# Age                                   int64
# Gender                                  str
# Academic_Performance_(GPA)            int64
# Study_Hours_Per_Week                  int64
# Social_Media_Usage_(Hours_per_day)    int64
# Sleep_Duration_(Hours_per_night)      int64
# Physical_Exercise_(Hours_per_week)    int64
# Family_Support                        int64
# Financial_Stress                      int64
# Peer_Pressure                         int64
# Relationship_Stress                   int64
# Mental_Stress_Level                   int64
# Counseling_Attendance                 int64
# Diet_Quality                          int64
# Stress_Coping_Mechanisms                str
# Cognitive_Distortions                 int64
# Family_Mental_Health_History            str
# Medical_Condition                       str
# Substance_Use                         int64
# dtype: object

# %%
data.corr(numeric_only=True)
# Out:
#                                          Age  Academic_Performance_(GPA)  \
# Age                                 1.000000                    0.001159
# Academic_Performance_(GPA)          0.001159                    1.000000
# Study_Hours_Per_Week                0.023549                   -0.000237
# Social_Media_Usage_(Hours_per_day) -0.002382                    0.033613
# Sleep_Duration_(Hours_per_night)    0.036756                   -0.017450
# Physical_Exercise_(Hours_per_week) -0.032789                    0.035845
# Family_Support                     -0.003340                    0.001262
# Financial_Stress                   -0.004682                    0.050622
# Peer_Pressure                       0.059751                    0.018018
# Relationship_Stress                -0.005101                    0.014869
# Mental_Stress_Level                -0.048228                   -0.036178
# Counseling_Attendance               0.053055                    0.045501
# ...
